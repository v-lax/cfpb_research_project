# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
survey=pd.read_csv('CFPB_All_Data.csv')
survey.head()
# Out:
#        Customer ID  Customer Number Meeting ID Number  Meeting Number Primary Coach: Full Name Organization: Account Name Survey Name Active Meeting Date State Zip Code  Gender Gender Denver Date of Birth  Age                    Race               Ethnicity                         Highest Education Achieved  Adults in the Household  Children in Household  Child Dependents Marital Status Head of Household  Household Size Presenting Issue Living Situation                 Status Employment Type Employment_Denver  Income Baseline Amount  Income Active Meeting Amount  Income Change  Monthly Gross Household Income                                Benefits        Income Supports   Health Insurance Banking Status at Time of First Meeting  Assets Balances Baseline Amount  Assets Balances Active Meeting Amount  Assets Balances Change  Assets Outcome Assets Outcome Meeting Date  Banking Outcome  Banking Outcome Meeting Number  Credit Score Baseline Amount  Credit Score Active Meeting Amount  \
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3241 entries, 0 to 3240
# Data columns (total 85 columns):
# Customer ID                                 3241 non-null object
# Customer Number                             3241 non-null int64
# Meeting ID Number                           3241 non-null object
# Meeting Number                              3238 non-null float64
# Primary Coach: Full Name                    3241 non-null object
# Organization: Account Name                  3241 non-null object
# Survey Name                                 3241 non-null object
# Active Meeting Date                         3241 non-null object
# State                                       2454 non-null object
# Zip Code                                    3179 non-null object
# Gender                                      1138 non-null object
# Gender Denver                               2255 non-null object
# Date of Birth                               3241 non-null object
# ...

# %%
# For every row that has Andy Collado as a coach, replace the value in CFPB Survey Method with 'Questions were read
# to the customer'

survey.loc[survey['Primary Coach: Full Name']=='Andy Collado','CFPB Survey Method']='Questions were read to the customer'

# %%
#This form of code is looking to go through each value in the "CFPB  Fin Well Being Total Response Value" column 
# and if there is a value in the row (i.e. not null or empty) I want to replace the value in the 'CFPB Abbr Fin Well Being
# Total Resp Val' with a null value. The code keeps coming out with error because the I think datatype is not the right
# datatype for Pandas. I have to look and see if there is another way to do it. 

for index,row in survey.head(n=5).iterrows():
    print(row[-2])
    if row[-2].isnull()==False:
        row[-1].replace(np.nan)

survey.head(5)
# Out:
# 38.0
# nan
# nan
# nan
# 8.0

# %%
#after we remove the values from the abreviated total response value I would have to remove the appropriate long form 
#score as well.

# %%
#remove other clinic coaches who do not have "CFPB Survey Method"

# %%
#Check to see if all customers have a respondent.

# %%
#
